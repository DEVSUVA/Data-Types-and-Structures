# %% [markdown]
# 1.  What are data structures, and why are they important?
# ans> Data structure is a way of organizing and storing data so that it can be   accessed and manipulated efficiently.
# Data structure is important because it is required to store all data in a sequential way so that it can be accessed and manipulated and also to use for later purposes.
#
# 2. Explain the difference between mutable and immutable data types with examples?
# ans> Mutable Data Types:- When the content or assigned value of a data types can be changed without changing their memory address is called Mutable data types.
# Example- List, Dictionary, Set. Here we can change or manipulate the value of these data types
# p = [4,9,7]
# print(id(p)) --> let us take memory location is a
# p.append(8)
# print(p)
# print(id(p)) --> let us take memory location is b
# here both a and b are same so its mutable data types
# Immutable Data Types:- When the content or assigned value of a data types cannot be changed without changing their memory address is called Immutable data types.
# Example- Int, Tuple
# S= 354
# print(id(s)) --> suppose the outcome of this is a
# s=s+1
# print(s)
# print(id(s)) --> suppose the outcome of this is b
# now a and b is the memory locations of s and both of them are totally different
#
# 3. What are the main differences between lists and tuples in Python?
# ans> The main differences between lists and tuples are list is mutable and defined with square bracket and tuple is immitable and defined with  parentheses.
# 4.  Describe how dictionaries store data?
# ans> Dictionaries store data as key-value pairs. Where keys are unique and immutable, while values can be of any data type.
# 5. Why might you use a set instead of a list in Python?
# ans> In a situation where i need unique value which can not be modified directly like suppose i want to store the colours i need and i dont want that anyone else add anyother colour whithout my consent.
# 6.  What is a string in Python, and how is it different from a list?
# ans> In python string is a immutable sqeuences of characters, enclosed in a single, double or tripple quotes.
# 7.  How do tuples ensure data integrity in Python?
# ans> Tuple is immutable data types so the value neither can be changed or manipulated without changing their memory location thus it ensures data integrity .
# 8. A hash table is a data structure which stores data in key-value pair and uses hash function to compute index in an underlying array where the value is stored.
# Ditionaries also uses hash table, where key can be any immutable or hashable data types and values can be any-thing.
# 9.  Can lists contain different data types in Python?
#  ans> yes, lists contain different data types in Python
# 10.  Explain why strings are immutable in Python?
# ans> In python, When the content or value once assigned to string, cannot be changed ater that without changing their memory addres.
# 11. What advantages do dictionaries offer over lists for certain tasks
# ans> Dictionaries store data as key–value pairs so we can assign the keys as per requirement and easily access the values as we wish which is not possible in case of list
# Example -- Like dictionarie is much helpfull while recording student data using their name as keys
# 12. Describe a scenario where using a tuple would be preferable over a list?
# and> Where ever we needed the immutable data types tuple is preferable over list, like storing date and time
# 13.  How do sets handle duplicate values in Python?
# ans> Using set data structure solves the duplicate value problem
# 14.  How does the “in” keyword work differently for lists and dictionaries?
# ans> In list "in" checks if the value exists in the list or not and in dictionaries "in" checks is the keys exsists or not?
# 15. Can you modify the elements of a tuple? Explain why or why not?
# ans> No elements of the tuple can not modified because it is an immutable data structure.
# 16.  What is a nested dictionary, and give an example of its use case?
# ans> Nested dictionary is a dictionary inside a dictionary
# Example -- { "Suvra": {"age": 25, "city": "Kolkata"}, "Suva": {"age": 22, "city": "Dilli"}}
# 17. Describe the time complexity of accessing elements in a dictionary?
# ans> Normally it is O(1) (constant time) and sometimes it becomes O(n) (rare, due to hash collisions) which is worst case.
# 18. In what situations are lists preferred over dictionaries?
# ans> When we dont need key value pairs and need a seuential access of data.
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# ans> In dictionaries data is stores as it is given, there is no sequential order.
# Beacuse of that no sequential order data retrieval depends on keys not on order.
# 20.  Explain the difference between a list and a dictionary in terms of data retrieval?
# ans> Data retrieval, in case list it is totally dependent on sequential order and in case of dictionaries it is based on key or values.

# %%
# 1) Write a code to create a string with your name and print it?
name = input("enter your name ")
print(name)
# Out:
# enter your nameSuvankar Debnath
# Suvankar Debnath

# %%
# 2) Write a code to find the length of the string "Hello World"?
string = "Hello World"
print(len(string))
# Out:
# 11

# %%
# 3) Write a code to slice the first 3 characters from the string "Python Programming"?
string = "Python Programming"
print(string[0:3])
# Out:
# Pyt

# %%
# 4) Write a code to convert the string "hello" to uppercase?
string = "hello"
print(string.upper())
# Out:
# HELLO

# %%
# 5) Write a code to replace the word "apple" with "orange" in the string "I like apple"?
string = "I like apple"
print(string.replace("apple","orange"))
# Out:
# I like orange

# %%
# 6) Write a code to create a list with numbers 1 to 5 and print it?
lst = list(range(1,6))
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7) Write a code to append the number 10 to the list [1, 2, 3, 4]
s = [1, 2, 3, 4]
s.append(10)
print(s)
# Out:
# [1, 2, 3, 4, 10]

# %%
#8) Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
s = [1, 2, 3, 4, 5]
s.remove(3)
print(s)
# Out:
# [1, 2, 4, 5]

# %%
# 9) Write a code to access the second element in the list ['a', 'b', 'c', 'd']
s = ['a', 'b', 'c', 'd']
a = s[1]
print(a)
# Out:
# b

# %%
# 10) Write a code to reverse the list [10, 20, 30, 40, 50]?
s = [10, 20, 30, 40, 50]
a = s[-1::-1]
print(a)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11) Write a code to create a tuple with the elements 100, 200, 300 and print it?
t = (100,200,300)
print(t)
# Out:
# (100, 200, 300)

# %%
# 12) Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
t = ('red', 'green', 'blue', 'yellow')
print(t[-2])
# Out:
# blue

# %%
# 13) Write a code to find the minimum number in the tuple (10, 20, 5, 15)
t= (10, 20, 5, 15)
print(min(t))
# Out:
# 5

# %%
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t = ('dog', 'cat', 'rabbit')
print(t.index("cat"))
# Out:
# 1

# %%
#  15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
t =("mango", "apple", "banana")
fruit = "kiwi"
if fruit in t:
    print("kiwi is in the tuple")
else:
    print("kiwi is not in the tuple")

# %%
#  16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.
s = {'a', 'b', 'c'}
print(s)
# Out:
# {'b', 'c', 'a'}

# %%
#  17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
#  18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.
s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
#  19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
s1 = {1, 2, 3}
s2 = {3, 4, 5}
s3 = s1.union(s2)
print(s3)
# Out:
# {1, 2, 3, 4, 5}

# %%
#  20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
s1 = {1, 2, 3}
s2= {2, 3, 4}
s3= s1.intersection(s2)
print(s3)
# Out:
# {2, 3}

# %%
#  21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
D= {"name": "Suvankar Debnath", "age": 26, "city": "kolkata" }
print(D)
# Out:
# {'name': 'Suvankar Debnath', 'age': 26, 'city': 'kolkata'}

# %%
#  22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
D ={'name': 'John', 'age': 25}
D.update({"country": "USA"})
print(D)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#  23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
D = {'name': 'Alice', 'age': 30}
print(D['name'])
# Out:
# Alice

# %%
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
D = {'name': 'Bob', 'age': 22, 'city': 'New York'}
D.pop("age")
print(D)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#  25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
D = {'name': 'Alice', 'city': 'Paris'}
print("city" in D)
# Out:
# True

# %%
#  26. Write a code to create a list, a tuple, and a dictionary, and print them all.
l = [1, 2, 3, 4, 5]
t = (10, 20, 30, 40, 50)
D = {'name': 'Alice', 'age': 25, 'city': 'Kolkata'}
print("List:", l)
print("Tuple:", t)
print("Dictionary:", D)
# Out:
# List: [1, 2, 3, 4, 5]
# Tuple: (10, 20, 30, 40, 50)
# Dictionary: {'name': 'Alice', 'age': 25, 'city': 'Kolkata'}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the  result.(replaced)
import random

n = []
for i in range(5):
    n.append(random.randint(1, 100))

n.sort()
print(n)
# Out:
# [1, 8, 18, 59, 63]

# %%
# 28. Write a code to create a list with strings and print the element at the third index
l = ["Kolkata","mumbai","chennai","dilli"]
print(l[2])
# Out:
# chennai

# %%
# 29. Write a code to combine two dictionaries into one and print the result.
D = {'name': 'Alice', 'age': 25, 'city': 'Kolkata'}
D1 = {'name': 'Bob', 'age': 22, 'city': 'New York'}
D.update(D1)
print(D)
# Out:
# {'name': 'Bob', 'age': 22, 'city': 'New York'}

# %%
# 30. Write a code to convert a list of strings into a set
l = ["Kolkata","mumbai","chennai","dilli"]
d =set(l)
print(type(d))
# Out:
# <class 'set'>
